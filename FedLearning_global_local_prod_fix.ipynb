# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/828HW2
# Out:
# /content/drive/MyDrive/828HW2

# %%
# !git clone https://github.com/KarhouTam/FL-bench.git
# Out:
# fatal: destination path 'FL-bench' already exists and is not an empty directory.

# %%
# %cd FL-bench
# Out:
# /content/drive/MyDrive/828HW2/FL-bench

# %%
# %cd data/utils
# Out:
# /content/drive/MyDrive/828HW2/FL-bench/data/utils

# %%
# !sh ../download/tiny_imagenet.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: tiny-imagenet-200/val/images/val_3979.JPEG
#   inflating: tiny-imagenet-200/val/images/val_3963.JPEG
#   inflating: tiny-imagenet-200/val/images/val_7199.JPEG
#   inflating: tiny-imagenet-200/val/images/val_2752.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9687.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9407.JPEG
#   inflating: tiny-imagenet-200/val/images/val_3603.JPEG
#   inflating: tiny-imagenet-200/val/images/val_3412.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6982.JPEG
#   inflating: tiny-imagenet-200/val/images/val_8496.JPEG
#   inflating: tiny-imagenet-200/val/images/val_7332.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9241.JPEG
#   inflating: tiny-imagenet-200/val/images/val_4196.JPEG
#   inflating: tiny-imagenet-200/val/images/val_5980.JPEG
#   inflating: tiny-imagenet-200/val/images/val_6697.JPEG
#   inflating: tiny-imagenet-200/val/images/val_9969.JPEG
# ...

# %%
# !pip install path.py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install visdom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408216 sha256=1fb94d88f77de7ebaa6f3851c4ecd93bc14cb82b2d99647f2be71ce5f2bb760a
#   Stored in directory: /root/.cache/pip/wheels/58/9e/14/30f7cc4dafdd4d602fb00ca33c6edd1424fc0f5df10a02e060
# Successfully built visdom
# ...

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python run.py -d tiny_imagenet -c 20 -cn 20

# %%
# %cd ../../
# Out:
# /content/drive/MyDrive/828HW2/FL-bench

# %%
# %cd src/server
# Out:
# /content/drive/MyDrive/828HW2/FL-bench/src/server

# %%
# !python fedavg.py --global_epoch 250 --local_epoch 2 --model res18 -d tiny_imagenet --visible 0 -jr 0.4 --client_cuda 1 --server_cuda 1 --save_log 1 --save_model 1 --save_fig 1 --save_metrics 1
# Out:
# ==================== ALGORITHM: FedAvg ====================
# Experiment Arguments:
# {
#     'model': 'res18',
#     'dataset': 'tiny_imagenet',
#     'seed': 42,
#     'join_ratio': 0.4,
#     'global_epoch': 250,
#     'local_epoch': 2,
#     'finetune_epoch': 0,
#     'test_gap': 100,
#     'eval_test': 1,
#     'eval_train': 0,
#     'local_lr': 0.01,
#     'momentum': 0.0,
#     'weight_decay': 0.0,
#     'verbose_gap': 100000,
#     'batch_size': 32,
#     'server_cuda': 1,
#     'client_cuda': 1,
#     'visible': 0,
#     'save_log': 1,
#     'save_model': 1,
#     'save_fig': 1,
#     'save_metrics': 1,
#     'dataset_args': {
#         'dataset': 'tiny_imagenet',
#         'client_num_in_total': 20,
#         'fraction': 0.5,
#         'seed': 42,
#         'split': 'sample',
#         'classes_per_client': 20
#     }
# }
# Training... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 2:25:52
# ==================== FedAvg TEST RESULTS: ====================
# {
# ...

# %%
# !python fedavg.py --global_epoch 100 --local_epoch 5 --model res18 -d tiny_imagenet --visible 0 -jr 0.4 --client_cuda 1 --server_cuda 1 --save_log 1 --save_model 1 --save_fig 1 --save_metrics 1
# Out:
# ==================== ALGORITHM: FedAvg ====================
# Experiment Arguments:
# {
#     'model': 'res18',
#     'dataset': 'tiny_imagenet',
#     'seed': 42,
#     'join_ratio': 0.4,
#     'global_epoch': 100,
#     'local_epoch': 5,
#     'finetune_epoch': 0,
#     'test_gap': 100,
#     'eval_test': 1,
#     'eval_train': 0,
#     'local_lr': 0.01,
#     'momentum': 0.0,
#     'weight_decay': 0.0,
#     'verbose_gap': 100000,
#     'batch_size': 32,
#     'server_cuda': 1,
#     'client_cuda': 1,
#     'visible': 0,
#     'save_log': 1,
#     'save_model': 1,
#     'save_fig': 1,
#     'save_metrics': 1,
#     'dataset_args': {
#         'dataset': 'tiny_imagenet',
#         'client_num_in_total': 20,
#         'fraction': 0.5,
#         'seed': 42,
#         'split': 'sample',
#         'classes_per_client': 20
#     }
# }
# Training... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 2:01:37
# ==================== FedAvg TEST RESULTS: ====================
# ...

# %%
# !python fedavg.py --global_epoch 50 --local_epoch 10 --verbose 1 --model res18 -d tiny_imagenet --visible 0 -jr 0.4 --client_cuda 1 --server_cuda 1 --save_log 1 --save_model 1 --save_fig 1 --save_metrics 1
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 124MB/s]
# ==================== ALGORITHM: FedAvg ====================
# Experiment Arguments:
# {
#     'model': 'res18',
#     'dataset': 'tiny_imagenet',
#     'seed': 42,
#     'join_ratio': 0.4,
#     'global_epoch': 50,
#     'local_epoch': 10,
#     'finetune_epoch': 0,
#     'test_gap': 100,
#     'eval_test': 1,
#     'eval_train': 0,
#     'local_lr': 0.01,
#     'momentum': 0.0,
#     'weight_decay': 0.0,
#     'verbose_gap': 1,
#     'batch_size': 32,
#     'server_cuda': 1,
#     'client_cuda': 1,
#     'visible': 0,
#     'save_log': 1,
#     'save_model': 1,
#     'save_fig': 1,
#     'save_metrics': 1,
#     'dataset_args': {
#         'dataset': 'tiny_imagenet',
#         'client_num_in_total': 20,
#         'fraction': 0.5,
#         'seed': 42,
#         'split': 'sample',
# ...

# %%
# !python fedavg.py --global_epoch 25 --local_epoch 20 --model res18 -d tiny_imagenet --visible 0 -jr 0.4 --client_cuda 1 --server_cuda 1 --save_log 1 --save_model 1 --save_fig 1 --save_metrics 1
# Out:
# ==================== ALGORITHM: FedAvg ====================
# Experiment Arguments:
# {
#     'model': 'res18',
#     'dataset': 'tiny_imagenet',
#     'seed': 42,
#     'join_ratio': 0.4,
#     'global_epoch': 25,
#     'local_epoch': 20,
#     'finetune_epoch': 0,
#     'test_gap': 100,
#     'eval_test': 1,
#     'eval_train': 0,
#     'local_lr': 0.01,
#     'momentum': 0.0,
#     'weight_decay': 0.0,
#     'verbose_gap': 100000,
#     'batch_size': 32,
#     'server_cuda': 1,
#     'client_cuda': 1,
#     'visible': 0,
#     'save_log': 1,
#     'save_model': 1,
#     'save_fig': 1,
#     'save_metrics': 1,
#     'dataset_args': {
#         'dataset': 'tiny_imagenet',
#         'client_num_in_total': 20,
#         'fraction': 0.5,
#         'seed': 42,
#         'split': 'sample',
#         'classes_per_client': 20
#     }
# }
# Training... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 1:30:23
# ==================== FedAvg TEST RESULTS: ====================
# {}
# ...

# %%
# %cd out
# Out:
# /content/drive/MyDrive/828HW2/FL-bench/out

# %%
# %cd FedAvg
# Out:
# /content/drive/MyDrive/828HW2/FL-bench/out/FedAvg

# %%
# %ls
# Out:
# data_file_epoch_gl100_le5_cn20.json  tiny_imagenet_ge250.jpeg
# data_file_epoch_gl250_le2_cn20.json  tiny_imagenet_ge25_acc_metrics.csv
# data_file_epoch_gl25_le20_cn20.json  tiny_imagenet_ge25.jpeg
# data_file_epoch_gl3_le4_cn20.json    tiny_imagenet_ge3_acc_metrics.csv
# data_file_epoch_gl50_le10_cn20.json  tiny_imagenet_ge3.jpeg
# tiny_imagenet_100_res18.pt           tiny_imagenet_ge50_acc_metrics.csv
# tiny_imagenet_250_res18.pt           tiny_imagenet_ge50.jpeg
# tiny_imagenet_25_res18.pt            tiny_imagenet_gl100_log.html
# tiny_imagenet_3_res18.pt             tiny_imagenet_gl250_log.html
# tiny_imagenet_50_res18.pt            tiny_imagenet_gl25_log.html
# tiny_imagenet_ge100_acc_metrics.csv  tiny_imagenet_gl3_log.html
# tiny_imagenet_ge100.jpeg             tiny_imagenet_gl50_log.html
# tiny_imagenet_ge250_acc_metrics.csv

# %%
global_epoch_num = [250, 100, 50, 25]
local_epoch_num = [2, 5, 10, 20]

# %%
for i in range(4):
  ge = global_epoch_num[i]
  le = local_epoch_num[i]
  import os

  current_path = os.getcwd()
  print("Current working directory:", current_path)

  

  json_file_name = "/data_file_epoch_gl" + str(ge) + "_le" + str(le) +"_cn20.json"
  metrics_csv = "/tiny_imagenet_ge" + str(ge) + "_acc_metrics.csv"

  full_path = os.path.join(current_path, json_file_name)

  with open(full_path, 'r') as file:
    python_object = json.load(file)

  print(python_object)
  break
# /content/drive/MyDrive/828HW2/FL-bench/out/FedAvg/data_file_epoch_gl100_le5_cn20.json

# data_file_epoch_gl100_le5_cn20.json
# data_file_epoch_gl250_le2_cn20
# data_file_epoch_gl250_le2_cn20
# data_file_epoch_gl250_le2_cn20
# Out:
# Current working directory: /content/drive/MyDrive/828HW2/FL-bench/out/FedAvg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-3dfc65dae27c> in <cell line: 1>()
#      14   full_path = os.path.join(current_path, json_file_name)
#      15
# ---> 16   with open(full_path, 'r') as file:
#      17     python_object = json.load(file)
#      18
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data_file_epoch_gl250_le2_cn20.json'

# %%
path = "/content/drive/MyDrive/828HW2/FL-bench/out/FedAvg/"
import json
global_epoch_num = [250, 100, 50, 25]
local_epoch_num = [2, 5, 10, 20]

for i in range(1):
  ge = global_epoch_num[i]
  le = local_epoch_num[i]


json_file_name = "data_file_epoch_gl" + str(ge) + "_le" + str(le) +"_cn20.json"
metrics_csv = "tiny_imagenet_ge" + str(ge) + "_acc_metrics.csv"
# print("output path is", output_path)

# The path of the json
path_json = path + json_file_name

# the path of the csv
path_csv = path + metrics_csv

with open(path_json, 'r') as file:
  data_250_small = json.load(file)


for i in range(5):
  cur_data = data_250_small[i]
  print(len(cur_data))
  test_correct = [entry['test_correct'] for entry in cur_data]
  test_size = cur_data[0]['test_size']
  accuracy = [100*correct / test_size for correct in test_correct]
  x = list(range(1, len(accuracy) + 1))
  model_name = "Model " + str(i+1)
  plt.plot(x, accuracy, label=model_name)
# Out:
# 178
# 202
# 204
# 228
# 214

# %%
# Import required libraries
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
for i in range(5):
  cur_data = data_250_small[i]
  print(len(cur_data))
  test_correct = [entry['test_correct'] for entry in cur_data]
  test_size = cur_data[0]['test_size']
  accuracy = [100*correct / test_size for correct in test_correct]
  x = list(range(1, len(accuracy) + 1))
  model_name = "Model " + str(i+1)
  plt.plot(x, accuracy, label=model_name)

# print(len(data_test_before_after_250))

# test_before = [entry["test_before"] for entry in data_test_before_after_250]
# test_after = [entry["test_after"] for entry in data_test_before_after_250]
# tmp = []
# for t in test_before:
#   tmp.append(t)
#   tmp.append(t)
# test_before = deepcopy(tmp)
# x = list(range(1, len(test_before) + 1))
# plt.plot(x, test_before, marker='o')

# test_correct = [entry['test_correct'] for entry in data]
# test_size = data[0]['test_size']
# accuracy = [correct / test_size for correct in test_correct]
# x = list(range(1, len(accuracy) + 1))

# # Plotting
# plt.plot(x, accuracy, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy')
plt.title('Test Accuracy vs. Epoch')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# 178
# 202
# 204
# 228
# 214

# %%
# %cd data/utils
# Out:
# /content/FL-bench/data/utils

# %%
# %cd ../../../
# Out:
# /content

# %%
# %cd ../../
# Out:
# /content/FL-bench

# %%
# %cd content/
# Out:
# /content

# %%
# %cd FL-bench/
# Out:
# /content/FL-bench

# %%
# %cd src/server
# Out:
# /content/FL-bench/src/server

# %%
# !python run.py -d tiny_imagenet -c 20 -cn 100
# Out:
# ^C

# %%
# !python fedavg.py --model res18 -d tiny_imagenet --visible 0 -jr 0.4 --client_cuda 1 --server_cuda 1
# Out:
# Traceback (most recent call last):
#   File "/content/FL-bench/src/server/fedavg.py", line 376, in <module>
#     server = FedAvgServer()
#   File "/content/FL-bench/src/server/fedavg.py", line 39, in __init__
#     with open(_PROJECT_DIR / "data" / self.args.dataset / "args.json", "r") as f:
# FileNotFoundError: [Errno 2] No such file or directory: Path('/content/FL-bench/data/tiny_imagenet/args.json')

# %%
# cd data/utils
# sh ../download/tiny_imagenet.sh
# python run.py -d tiny_imagenet -c 20 -cn 100
# cd ../../src/server
# python fedavg.py --model res18 -d tiny_imagenet --visible 0 -jr 0.4
